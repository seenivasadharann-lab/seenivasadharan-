# %% [markdown]
# 1. Add Two Numbers

# %%
a=10
b=5
print(a+b)
# Out:
# 15

# %% [markdown]
# 2. Subtract Two Numbers

# %%
a=10
b=5
c=(a-b)
print(c)
# Out:
# 5

# %% [markdown]
# 3. Multiply Two Numbers

# %%
a=10
b=5
c=a * b
print("Multiplication =", c)
# Out:
# Multiplication = 50

# %% [markdown]
# 4. Divide Two Numbers

# %%
a=10
b=5
print(a/b)
# Out:
# 2.0

# %% [markdown]
# 5. Find Remainder

# %%
a=10
b=3
print(a%b)
# Out:
# 1

# %% [markdown]
# 6. Find Square of a Number

# %%
num=5
square=num ** 2
print("Square =", square)
# Out:
# Square = 25

# %% [markdown]
# 7. Find Cube of a Number

# %%
num=5
cube=num**3
print(cube)
# Out:
# 125

# %% [markdown]
# 8. Calculate Area of Rectangle

# %%
l=10
b=5
print(l*b)
# Out:
# 50

# %% [markdown]
# 9. Calculate Area of Circle

# %%
r=7
p=3.14159
area=7*3.14159**2
print(area)
# Out:
# 69.08711409669999

# %% [markdown]
# 10. Calculate Simple Interest
#
# Formula: SI = (P × R × T) / 100

# %%
p=10000
r=5
t=2
si=(p*r*t)/100
print(si)
# Out:
# 1000.0

# %% [markdown]
# 11. Calculate Compound Interest
#
# Formula: CI = P(1 + R/100)^T - P

# %%
p=10000
r=5
t=2
ci=p*(1+r/100)**t-p
print(ci)
# Out:
# 1025.0

# %% [markdown]
# 12. Calculate Average Marks

# %%
m1=80
m2=75
m3=90
avg=(m1+m2+m3)/3
print("avg=",avg)
# Out:
# avg= 81.66666666666667

# %% [markdown]
# 13. Calculate Profit
#
# Formula: Profit = Selling Price − Cost Price

# %%
cp=500
sp=700
profit=(sp-cp)
print("profit=",profit)
# Out:
# profit= 200

# %% [markdown]
# 14. Calculate Loss profit
#
# Formula: Loss = Cost Price − Selling Price

# %%
cp=700
sp=500
loss=(cp-sp)
print("loss=",loss)
# Out:
# loss= 200

# %% [markdown]
# 15. Calculate Monthly Savings
#
# Formula: Savings = Income − Expenses

# %%
income = 5000
expenses = 2200
Savings =(income - expenses)
print=(savings)

# %% [markdown]
# 16. Largest of 2 Numbers

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

if a > b:
    print("Largest =", a)
else:
    print("Largest =", b)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_3363/4244304701.py in <cell line: 0>()
# ----> 1 a = int(input("Enter first number: "))
#       2 b = int(input("Enter second number: "))
#       3
#       4 if a > b:
#       5     print("Largest =", a)
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %% [markdown]
# 17. Largest of 3 Numbers

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))

if a > b and a > c:
    print("Largest =", a)
elif b > c:
    print("Largest =", b)
else:
    print("Largest =", c)
# Out:
# Enter first number: 10
# Enter second number: 25
# Enter third number: 15
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3363/2859695527.py in <cell line: 0>()
#       6     print("Largest =", a)
#       7 elif b > c:
# ----> 8     print("Largest =", b)
#       9 else:
#      10     print("Largest =", c)
#
# TypeError: 'int' object is not callable

# %% [markdown]
# 18. Smallest of 3 Numbers

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))

if a < b and a < c:
    print("Smallest =", a)
elif b < c:
    print("Smallest =", b)
else:
    print("Smallest =", c)
# Out:
# Enter first number: 10
# Enter second number: 25
# Enter third number: 15
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3363/1278487229.py in <cell line: 0>()
#       4
#       5 if a < b and a < c:
# ----> 6     print("Smallest =", a)
#       7 elif b < c:
#       8     print("Smallest =", b)
#
# TypeError: 'int' object is not callable

# %% [markdown]
# 19. Leap Year

# %%
year = int(input("Enter year: "))

if year % 4 == 0:
    print("Leap Year")
else:
    print("Not a Leap Year")
# Out:
# Enter year: 2003
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3363/922168194.py in <cell line: 0>()
#       4     print("Leap Year")
#       5 else:
# ----> 6     print("Not a Leap Year")
#
# TypeError: 'int' object is not callable

# %% [markdown]
# 20. Voting Eligibility

# %%
age = int(input("Enter age: "))

if age >= 18:
    print("Eligible for Voting")
else:
    print("Not Eligible for Voting")
# Out:
# Enter age: 20
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3363/424992751.py in <cell line: 0>()
#       2
#       3 if age >= 18:
# ----> 4     print("Eligible for Voting")
#       5 else:
#       6     print("Not Eligible for Voting")
#
# TypeError: 'int' object is not callable

# %% [markdown]
# 21. Grade Calculator

# %%
marks = int(input("Enter marks: "))

if marks >= 90:
    print("Grade A")
elif marks >= 75:
    print("Grade B")
elif marks >= 50:
    print("Grade C")
else:
    print("Fail")
# Out:
# Enter marks: 59
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3363/3826919824.py in <cell line: 0>()
#       6     print("Grade B")
#       7 elif marks >= 50:
# ----> 8     print("Grade C")
#       9 else:
#      10     print("Fail")
#
# TypeError: 'int' object is not callable

# %% [markdown]
# 22. Profit or Loss

# %%
cp = float(input("Enter Cost Price: "))
sp = float(input("Enter Selling Price: "))

if sp > cp:
    print("Profit =", sp - cp)
elif cp > sp:
    print("Loss =", cp - sp)
else:
    print("No Profit No Loss")
# Out:
# Enter Cost Price: 90
# Enter Selling Price: 100
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3363/1271921060.py in <cell line: 0>()
#       3
#       4 if sp > cp:
# ----> 5     print("Profit =", sp - cp)
#       6 elif cp > sp:
#       7     print("Loss =", cp - sp)
#
# TypeError: 'int' object is not callable

# %% [markdown]
# 23. ATM Withdrawal Validation

# %%
balance = float(input("Enter Balance: "))
amount = float(input("Enter Withdrawal Amount: "))

if amount <= balance:
    print("Withdrawal Successful")
else:
    print("Insufficient Balance")
# Out:
# Enter Balance: 1000
# Enter Withdrawal Amount: 700
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3363/272847422.py in <cell line: 0>()
#       3
#       4 if amount <= balance:
# ----> 5     print("Withdrawal Successful")
#       6 else:
#       7     print("Insufficient Balance")
#
# TypeError: 'int' object is not callable

# %% [markdown]
# 24. Electricity Bill

# %%
units = int(input("Enter Units Consumed: "))

if units <= 100:
    bill = units * 2
elif units <= 200:
    bill = units * 3
else:
    bill = units * 5

print("Bill Amount =", bill)
# Out:
# Enter Units Consumed: 100
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3363/3018325717.py in <cell line: 0>()
#       8     bill = units * 5
#       9
# ---> 10 print("Bill Amount =", bill)
#
# TypeError: 'int' object is not callable

# %% [markdown]
# 25. Divisible by 5 and 11

# %%
num = int(input("Enter a number: "))

if num % 5 == 0 and num % 11 == 0:
    print("Divisible by 5 and 11")
else:
    print("Not Divisible by 5 and 11")
# Out:
# Enter a number: 3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3363/1399356634.py in <cell line: 0>()
#       4     print("Divisible by 5 and 11")
#       5 else:
# ----> 6     print("Not Divisible by 5 and 11")
#
# TypeError: 'int' object is not callable

# %% [markdown]
# 26. Vowel or Consonant

# %%
ch = input("Enter a character: ")

if ch in "aeiouAEIOU":
    print("Vowel")
else:
    print("Consonant")
# Out:
# Enter a character: a
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3363/1758239678.py in <cell line: 0>()
#       2
#       3 if ch in "aeiouAEIOU":
# ----> 4     print("Vowel")
#       5 else:
#       6     print("Consonant")
#
# TypeError: 'int' object is not callable

# %% [markdown]
# 27. Pass or Fail

# %%
marks = int(input("Enter marks: "))

if marks >= 35:
    print("Pass")
else:
    print("Fail")
# Out:
# Enter marks: 10
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3363/345628753.py in <cell line: 0>()
#       4     print("Pass")
#       5 else:
# ----> 6     print("Fail")
#
# TypeError: 'int' object is not callable

# %% [markdown]
# 28. Age Category (Child, Adult, Senior Citizen)

# %%
age = int(input("Enter age: "))

if age < 18:
    print("Child")
elif age < 60:
    print("Adult")
else:
    print("Senior Citizen")
# Out:
# Enter age: 20
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3363/1648182947.py in <cell line: 0>()
#       4     print("Child")
#       5 elif age < 60:
# ----> 6     print("Adult")
#       7 else:
#       8     print("Senior Citizen")
#
# TypeError: 'int' object is not callable
